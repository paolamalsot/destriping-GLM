# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path

_here = Path(os.path.abspath(""))
while not (_here / "pixi.toml").exists():
    _here = _here.parent
    if _here == _here.parent:
        raise RuntimeError("Could not find repo root")
os.chdir(_here)

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

from src.experiments_analysis.sensitivity_analysis_pipeline import (
    make_config,
# SKIPPED:     run_sensitivity_analysis_multi_seed,
    build_metrics_df,
    sensitivity_barplot,
    print_chosen_alphas,
)

BASELINES_PATH = "experiments/benchmark_output_files/sensitivity_analysis/simulation_baselines.yaml"
RUNS_PATH = "experiments/benchmark_output_files/sensitivity_analysis/simulation_split.yaml"
cfg = make_config(BASELINES_PATH, RUNS_PATH)
output_dir = cfg["output_dir"]
figures_output_dir = Path(cfg["figures_output_dir"])
figures_output_dir.mkdir(exist_ok=True, parents=True)
Path(output_dir).mkdir(parents=True, exist_ok=True)
# Out:
# bioimageio_utils.py (2): pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %% [markdown]
# ## Run analysis pipeline

# %%
# SKIPPED: run_sensitivity_analysis_multi_seed(cfg)

# %% [markdown]
# ## Results table + barplot

# %%
from src.experiments_analysis.sensitivity_analysis_pipeline import simulation_data_plots

simulation_data_plots(output_dir, figures_output_dir, "split")
# Out:
# /cluster/home/pmalsot/destriping-GLM-rebuttals/src/experiments_analysis/sensitivity_analysis_pipeline.py:895: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis.set_xticklabels(axis.get_xticklabels(), rotation=45, ha="right")
# /cluster/home/pmalsot/destriping-GLM-rebuttals/src/experiments_analysis/analysis.py:280: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   destriped_summary_df.groupby("name").apply(select_method).reset_index(drop=True)
#                                 name  \
# 0                        ours (p=5%)
# 1                        ours (p=5%)
# 2                        ours (p=5%)
# 3                       ours (p=10%)
# 4                       ours (p=10%)
# 5                       ours (p=10%)
# 6                       ours (p=50%)
# 7                       ours (p=50%)
# 8                       ours (p=50%)
# 9                       ours (p=90%)
# 10                      ours (p=90%)
# 11                      ours (p=90%)
# 12                       ours (p=5%)
# 13                       ours (p=5%)
# 14                       ours (p=5%)
# 15                      ours (p=10%)
# 16                      ours (p=10%)
# 17                      ours (p=10%)
# 18                      ours (p=50%)
# 19                      ours (p=50%)
# 20                      ours (p=50%)
# 21                      ours (p=90%)
# 22                      ours (p=90%)
# 23                      ours (p=90%)
# 24                       ours (p=5%)
# 25                       ours (p=5%)
# 26                       ours (p=5%)
# 27                      ours (p=10%)
# 28                      ours (p=10%)
# 29                      ours (p=10%)
# 30                      ours (p=50%)
# 31                      ours (p=50%)
# 32                      ours (p=50%)
# 33                      ours (p=90%)
# 34                      ours (p=90%)
# 35                      ours (p=90%)
# 36                              ours
# 37             ours (collapse label)
# 38                          original
# 39                           b2c-sym
# 40                               b2c
# 41  expected_spatial_data_wo_stripes
#
#     Log-space L2 error in $(\mathbf{h}, \mathbf{w})$  \
# 0                                           0.063048
# 1                                           0.063048
# 2                                           0.063048
# 3                                           0.063062
# 4                                           0.063062
# 5                                           0.063062
# 6                                           0.064892
# 7                                           0.064892
# 8                                           0.064892
# 9                                           0.069322
# 10                                          0.069322
# 11                                          0.069322
# 12                                          0.062916
# 13                                          0.062916
# 14                                          0.062916
# 15                                          0.063949
# 16                                          0.063949
# 17                                          0.063949
# 18                                          0.067280
# 19                                          0.067280
# 20                                          0.067280
# 21                                          0.068911
# 22                                          0.068911
# 23                                          0.068911
# 24                                          0.063242
# 25                                          0.063242
# 26                                          0.063242
# 27                                          0.063028
# 28                                          0.063028
# 29                                          0.063028
# 30                                          0.065503
# 31                                          0.065503
# 32                                          0.065503
# 33                                          0.069117
# 34                                          0.069117
# 35                                          0.069117
# 36                                          0.062395
# 37                                          0.305593
# 38                                          0.478410
# 39                                          8.930994
# 40                                               NaN
# 41                                               NaN
#
#     Cosine error in $k^{corr}$
# 0                     0.001870
# 1                     0.001832
# 2                     0.001859
# 3                     0.001872
# 4                     0.001920
# 5                     0.001864
# 6                     0.002033
# 7                     0.002123
# 8                     0.002047
# 9                     0.002279
# 10                    0.002269
# 11                    0.002256
# 12                    0.001870
# 13                    0.001832
# 14                    0.001859
# 15                    0.001872
# 16                    0.001920
# 17                    0.001864
# 18                    0.002033
# 19                    0.002123
# 20                    0.002047
# 21                    0.002279
# 22                    0.002269
# 23                    0.002256
# 24                    0.001870
# 25                    0.001832
# 26                    0.001859
# 27                    0.001872
# 28                    0.001920
# 29                    0.001864
# 30                    0.002033
# 31                    0.002123
# 32                    0.002047
# 33                    0.002279
# 34                    0.002269
# 35                    0.002256
# 36                    0.001814
# 37                    0.034472
# 38                    0.091343
# 39                    0.181233
# 40                    0.185120
# 41                    0.013806
# /cluster/home/pmalsot/destriping-GLM-rebuttals/src/experiments_analysis/sensitivity_analysis_pipeline.py:441: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# /cluster/home/pmalsot/destriping-GLM-rebuttals/src/experiments_analysis/sensitivity_analysis_pipeline.py:441: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")

# %%
from src.experiments_analysis.sensitivity_analysis_pipeline import convergence_barplot

ax = convergence_barplot(output_dir, experiment_type="split")
plt.show()
# Out:
# /cluster/home/pmalsot/destriping-GLM-rebuttals/src/experiments_analysis/sensitivity_analysis_pipeline.py:1272: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")

# %% [markdown]
# ## Chosen alpha per model

# %%
print_chosen_alphas(RUNS_PATH)
# Out:
# Chosen alpha:
# seed            42       64       754
# run
# p_split_10  0.00001  0.00001  0.00001
# p_split_5   0.00001  0.00001  0.00001
# p_split_50  0.00001  0.00001  0.00001
# p_split_90  0.00001  0.00001  0.00001
#
# Boundary hit wrt full CV grid (MIN / MAX / ok):
# seed        42   64   754
# run
# p_split_10  MIN  MIN  MIN
# p_split_5   MIN  MIN  MIN
# p_split_50  MIN  MIN  MIN
# p_split_90  MIN  MIN  MIN
#            run  seed    alpha  grid_min  grid_max boundary_side
# 0    p_split_5    42  0.00001   0.00001      10.0           MIN
# 1   p_split_10    42  0.00001   0.00001      10.0           MIN
# 2   p_split_50    42  0.00001   0.00001      10.0           MIN
# 3   p_split_90    42  0.00001   0.00001      10.0           MIN
# 4    p_split_5    64  0.00001   0.00001      10.0           MIN
# 5   p_split_10    64  0.00001   0.00001      10.0           MIN
# 6   p_split_50    64  0.00001   0.00001      10.0           MIN
# 7   p_split_90    64  0.00001   0.00001      10.0           MIN
# 8    p_split_5   754  0.00001   0.00001      10.0           MIN
# 9   p_split_10   754  0.00001   0.00001      10.0           MIN
# 10  p_split_50   754  0.00001   0.00001      10.0           MIN
# 11  p_split_90   754  0.00001   0.00001      10.0           MIN
