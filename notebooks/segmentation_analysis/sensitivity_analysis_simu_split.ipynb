# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path

_here = Path(os.path.abspath(""))
while not (_here / "pixi.toml").exists():
    _here = _here.parent
    if _here == _here.parent:
        raise RuntimeError("Could not find repo root")
os.chdir(_here)

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

from src.experiments_analysis.sensitivity_analysis_pipeline import (
    make_config,
    run_sensitivity_analysis_multi_seed,
    build_metrics_df,
    sensitivity_barplot,
    print_chosen_alphas,
)

BASELINES_PATH = "experiments/benchmark_output_files/sensitivity_analysis/simulation_baselines.yaml"
RUNS_PATH = "experiments/benchmark_output_files/sensitivity_analysis/simulation_split.yaml"
cfg = make_config(BASELINES_PATH, RUNS_PATH)
output_dir = cfg["output_dir"]
figures_output_dir = Path(cfg["figures_output_dir"])
figures_output_dir.mkdir(exist_ok=True, parents=True)
Path(output_dir).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Run analysis pipeline

# %%
run_sensitivity_analysis_multi_seed(cfg)
# Out:
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_42__p_split_5: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_42__p_split_5: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_42__p_split_10: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_42__p_split_10: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_42__p_split_50: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_42__p_split_50: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_42__p_split_90: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_42__p_split_90: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_64__p_split_5: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_64__p_split_5: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_64__p_split_10: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_64__p_split_10: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_64__p_split_50: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_64__p_split_50: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_64__p_split_90: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_64__p_split_90: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_754__p_split_5: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_754__p_split_5: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_754__p_split_10: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_754__p_split_10: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_754__p_split_50: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_754__p_split_50: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_754__p_split_90: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for seed_754__p_split_90: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for ours: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for ours: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for collapse_label: Metrics: 4 missing indices in h. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/destriping/GLUM/get_metrics_dist.py:17: UserWarning: computing sol metrics for collapse_label: Metrics: 3 missing indices in w. Filling with ones.
#   warnings.warn(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/analysis.py:243: UserWarning: NaN inf in the following destriped data: ['b2c-sym-c_mean']
#   warn(f"NaN inf in the following destriped data: {list_nan}")
#                                 name converged
# 0                 seed_42__p_split_5      True
# 1                seed_42__p_split_10      True
# 2                seed_42__p_split_50      True
# 3                seed_42__p_split_90      True
# 4                 seed_64__p_split_5      True
# 5                seed_64__p_split_10      True
# 6                seed_64__p_split_50      True
# 7                seed_64__p_split_90      True
# 8                seed_754__p_split_5      True
# 9               seed_754__p_split_10      True
# 10              seed_754__p_split_50      True
# 11              seed_754__p_split_90      True
# 12                              ours      True
# 13                    collapse_label      True
# 14                    b2c-sym-c_mean       NaN
# 15                          original       NaN
# 16              dividing_99_quantile       NaN
# 17                               2SN       NaN
# 18                    GT_poisson_sol       NaN
# 19  expected_spatial_data_wo_stripes       NaN
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/analysis.py:279: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   destriped_summary_df.groupby("name").apply(select_method).reset_index(drop=True)
# 2SN 0
# GT_nbinom_sol 1
# GT_poisson_sol 2
# b2c-sym-c_mean 3
# collapse_label 4
# dividing_99_quantile 5
# expected_spatial_data_wo_stripes 6
# original 7
# ours 8
# seed_42__p_split_10 9
# seed_42__p_split_5 10
# seed_42__p_split_50 11
# seed_42__p_split_90 12
# seed_64__p_split_10 13
# seed_64__p_split_5 14
# seed_64__p_split_50 15
# seed_64__p_split_90 16
# seed_754__p_split_10 17
# seed_754__p_split_5 18
# seed_754__p_split_50 19
# seed_754__p_split_90 20

# %% [markdown]
# ## Results table + barplot

# %%
from src.experiments_analysis.sensitivity_analysis_pipeline import simulation_data_plots

simulation_data_plots(output_dir, figures_output_dir, "split")
# Out:
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/analysis_plots.py:873: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/sensitivity_analysis_pipeline.py:892: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/analysis.py:279: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   destriped_summary_df.groupby("name").apply(select_method).reset_index(drop=True)
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/analysis_plots.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selection["name"] = df_selection["name"].cat.remove_unused_categories()
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/analysis_plots.py:41: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'grey'}` instead.
#
#   sns.barplot(
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/analysis_plots.py:59: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'grey'}` instead.
#
#   sns.barplot(
#                                 name  \
# 0                        ours (p=5%)
# 1                        ours (p=5%)
# 2                        ours (p=5%)
# 3                       ours (p=10%)
# 4                       ours (p=10%)
# 5                       ours (p=10%)
# 6                       ours (p=50%)
# 7                       ours (p=50%)
# 8                       ours (p=50%)
# 9                       ours (p=90%)
# 10                      ours (p=90%)
# 11                      ours (p=90%)
# 12                       ours (p=5%)
# 13                       ours (p=5%)
# 14                       ours (p=5%)
# 15                      ours (p=10%)
# 16                      ours (p=10%)
# 17                      ours (p=10%)
# 18                      ours (p=50%)
# 19                      ours (p=50%)
# 20                      ours (p=50%)
# 21                      ours (p=90%)
# 22                      ours (p=90%)
# 23                      ours (p=90%)
# 24                       ours (p=5%)
# 25                       ours (p=5%)
# 26                       ours (p=5%)
# 27                      ours (p=10%)
# 28                      ours (p=10%)
# 29                      ours (p=10%)
# 30                      ours (p=50%)
# 31                      ours (p=50%)
# 32                      ours (p=50%)
# 33                      ours (p=90%)
# 34                      ours (p=90%)
# 35                      ours (p=90%)
# 36                          original
# 37                           b2c-sym
# 38                               b2c
# 39  expected_spatial_data_wo_stripes
#
#     Log-space L2 error in $(\mathbf{h}, \mathbf{w})$  \
# 0                                           0.167967
# 1                                           0.167967
# 2                                           0.167967
# 3                                           0.168388
# 4                                           0.168388
# 5                                           0.168388
# 6                                           0.110990
# 7                                           0.110990
# 8                                           0.110990
# 9                                           0.116624
# 10                                          0.116624
# 11                                          0.116624
# 12                                          0.277840
# 13                                          0.277840
# 14                                          0.277840
# 15                                          0.268283
# 16                                          0.268283
# 17                                          0.268283
# 18                                          0.284794
# 19                                          0.284794
# 20                                          0.284794
# 21                                          0.181186
# 22                                          0.181186
# 23                                          0.181186
# 24                                          0.121126
# 25                                          0.121126
# 26                                          0.121126
# 27                                          0.168406
# 28                                          0.168406
# 29                                          0.168406
# 30                                          0.174133
# 31                                          0.174133
# 32                                          0.174133
# 33                                          0.116580
# 34                                          0.116580
# 35                                          0.116580
# 36                                          0.478410
# 37                                          8.930994
# 38                                               NaN
# 39                                               NaN
#
#     Cosine error in $k^{corr}$
# 0                     0.009096
# 1                     0.025650
# 2                     0.005020
# 3                     0.009163
# 4                     0.023517
# 5                     0.009163
# 6                     0.004326
# 7                     0.027354
# 8                     0.009991
# 9                     0.004850
# 10                    0.011008
# 11                    0.004856
# 12                    0.009096
# 13                    0.025650
# 14                    0.005020
# 15                    0.009163
# 16                    0.023517
# 17                    0.009163
# 18                    0.004326
# 19                    0.027354
# 20                    0.009991
# 21                    0.004850
# 22                    0.011008
# 23                    0.004856
# 24                    0.009096
# 25                    0.025650
# 26                    0.005020
# 27                    0.009163
# 28                    0.023517
# 29                    0.009163
# 30                    0.004326
# 31                    0.027354
# 32                    0.009991
# 33                    0.004850
# 34                    0.011008
# 35                    0.004856
# 36                    0.091343
# 37                    0.181233
# 38                    0.185120
# 39                    0.013803
# ['ours (p=5%)', 'ours (p=10%)', 'ours (p=50%)', 'ours (p=90%)', 'original', 'b2c-sym']
# Categories (6, object): ['ours (p=5%)' < 'ours (p=10%)' < 'ours (p=50%)' < 'ours (p=90%)' < 'original' < 'b2c-sym']
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/sensitivity_analysis_pipeline.py:440: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   for n in methods_order:
# /Users/pmalsot/Documents_no_iCloud/destriping-GLM-rebuttals/src/experiments_analysis/sensitivity_analysis_pipeline.py:440: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   for n in methods_order:

# %%
from src.experiments_analysis.sensitivity_analysis_pipeline import convergence_barplot

ax = convergence_barplot(output_dir, experiment_type="split")
plt.show()
# Out:
# <string>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %% [markdown]
# ## Chosen alpha per model

# %%
print_chosen_alphas(RUNS_PATH)
# Out:
# Chosen alpha:
# seed             42        64        754
# run
# p_split_10  0.001000  0.004642  0.001000
# p_split_5   0.001000  0.004642  0.000215
# p_split_50  0.000215  0.004642  0.001000
# p_split_90  0.000215  0.001000  0.000215
#
# Boundary hit wrt full CV grid (MIN / MAX / ok):
# seed       42  64  754
# run
# p_split_10  ok  ok  ok
# p_split_5   ok  ok  ok
# p_split_50  ok  ok  ok
# p_split_90  ok  ok  ok
#            run  seed     alpha  grid_min  grid_max boundary_side
# 0    p_split_5    42  0.001000   0.00001      10.0            ok
# 1   p_split_10    42  0.001000   0.00001      10.0            ok
# 2   p_split_50    42  0.000215   0.00001      10.0            ok
# 3   p_split_90    42  0.000215   0.00001      10.0            ok
# 4    p_split_5    64  0.004642   0.00001      10.0            ok
# 5   p_split_10    64  0.004642   0.00001      10.0            ok
# 6   p_split_50    64  0.004642   0.00001      10.0            ok
# 7   p_split_90    64  0.001000   0.00001      10.0            ok
# 8    p_split_5   754  0.000215   0.00001      10.0            ok
# 9   p_split_10   754  0.001000   0.00001      10.0            ok
# 10  p_split_50   754  0.001000   0.00001      10.0            ok
# 11  p_split_90   754  0.000215   0.00001      10.0            ok
